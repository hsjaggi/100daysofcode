# %% [markdown]
# if-else
#
# Conditional statements are fundamental to programming as they allow the execution of specific code blocks based on certain conditions. In Python, the if-else statement is a powerful tool for incorporating decision-making logic into your programs.
#
# The if Statement:
# if (condition):
#
# #Executes this block if condition is true
#
# The if statement is used to execute a block of code if a specified condition is True.
#
# ![image.png](attachment:cef5df75-46a9-4e8d-9c5b-26c386250c20.png)

# %%
x = 6
if x > 5:
    print("x is greater than 5")
print("Outside if condition")
# Out:
# x is greater than 5
# Outside if condition

# %% [markdown]
# The if-else statement :
# if (condition):
#
# #Executes this block if condition is true
#
# else:
#
# #Executes this block if condition is false

# %%
i = 31
if (i < 25):
	print("i is smaller than 25 , this is if Block")
else:
	print("i is greater than 25, this is else Block")
print("out of if and else Block")
# Out:
# i is greater than 25, this is else Block
# out of if and else Block

# %% [markdown]
# Short Hand if-else statement
# This can be used to write the if-else statements in a single line where only one statement is needed in both the if and else blocks.
#
# Syntax:
#
# statement_when_True if condition else statement_when_False

# %%
i = 10
print(True) if i < 15 else print(False)
# Out:
# True

# %% [markdown]
# The elif statement:
# if (condition 1):
#
#  #Executes this block if condition 1 is true
#
# elif (condition 2):
#
#  #Executes this block if condition 2 is true
#
# else:
#
# #Executes this block if condition 1 and 2 is false
#
# The elif statement allows you to check multiple conditions in sequence. It comes after an if statement and before an optional else statement.

# %%
x = 0

if x > 0:
    print("x is positive")
elif x < 0:
    print("x is negative")
else:
    print("x is zero")
# Out:
# x is zero

# %% [markdown]
# ![image.png](attachment:d82b51c0-98fb-4218-b555-16c6e4aece95.png)

# %% [markdown]
# Nested if-else Statements:
# The if-else statement can be nested, allowing for more complex decision-making structures.
#
# Nested_if
#
# ![image.png](attachment:bc54f962-bff8-4599-aab8-bbef2ba880fa.png)

# %%
num = 4
if num > 0:
    if num < 10:
    	print("The number is positive and less than 10.")
else:
    print("The number is less than or equal to 0")
# Out:
# The number is positive and less than 10.
